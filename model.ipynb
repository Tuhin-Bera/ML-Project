# %%
# !git clone https://github.com/Achinta005/ML-Project.git
# %cd ML-Project

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Dataset/output_dataframe.csv")
# Out:
# /tmp/ipython-input-226544729.py:2: DtypeWarning: Columns (10,14,15,16,17,18,19,21,26,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/Dataset/output_dataframe.csv")

# %%
df.head(20)
# Out:
#        LastName FirstName  DatasetID             Dataset  \
# 0   Cornelissen  Johannes         37  Sheffield Database
# 1   Cornelissen  Johannes         37  Sheffield Database
# 2   Cornelissen  Johannes         37  Sheffield Database
# 3   Cornelissen  Johannes         37  Sheffield Database
# 4   Cornelissen  Johannes         37  Sheffield Database
# 5   Cornelissen  Johannes         37  Sheffield Database
# 6   Cornelissen  Johannes         37  Sheffield Database
# 7   Cornelissen  Johannes         37  Sheffield Database
# 8   Cornelissen  Johannes         37  Sheffield Database
# 9   Cornelissen  Johannes         37  Sheffield Database
# 10  Cornelissen  Johannes         37  Sheffield Database
# 11  Cornelissen  Johannes         37  Sheffield Database
# 12  Cornelissen  Johannes         37  Sheffield Database
# 13  Cornelissen  Johannes         37  Sheffield Database
# 14  Cornelissen  Johannes         37  Sheffield Database
# ...

# %%
# !git add .

# %%
# !git commit -m "message"
